# %% [markdown]
# <a href="https://colab.research.google.com/github/karynaur/Breaking-Bad/blob/main/torch_beginner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# All about torch.tensor
#
# 1. Datatype
# 2. A flexible datatype

# %%
import torch

# %%
torch.tensor(3.)
# Out:
# tensor(3.)

# %%
torch.tensor([3,4.])
# Out:
# tensor([3., 4.])

# %%
torch.tensor([[2,3],[3,4.]])
# Out:
# tensor([[2., 3.],
#         [3., 4.]])

# %% [markdown]
# Even derivatives

# %%
x = torch.tensor(3., requires_grad=True)

y = 2 * x

# dy/dx = 2

y.backward()
print(x.grad)
# Out:
# tensor(2.)

# %% [markdown]
# Cuda!

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
a = torch.tensor([[3., 4], [4, 5]], device=device)

# %%
a
# Out:
# tensor([[3., 4.],
#         [4., 5.]], device='cuda:0')

# %%
a.to('cpu')
# Out:
# tensor([[3., 4.],
#         [4., 5.]])

# %%
a
# Out:
# tensor([[3., 4.],
#         [4., 5.]], device='cuda:0')

# %%
a.shape
# Out:
# torch.Size([2, 2])

# %%
a = a.view([1,4])

# %%
a
# Out:
# tensor([[3., 4., 4., 5.]], device='cuda:0')

# %%
a.reshape(1,4)
# Out:
# tensor([[3., 4., 4., 5.]], device='cuda:0')

# %%
a
# Out:
# tensor([[3., 4.],
#         [4., 5.]], device='cuda:0')

# %% [markdown]
# Everything is a tensor!

# %%
import ipywidgets as widgets

btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
from PIL import Image
import io

img = Image.open(io.BytesIO(btn_upload.data[-1]))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x1000 at 0x7FD1A15BC810>

# %%
img.size
# Out:
# (700, 1000)

# %%
from torchvision import transforms

tr = transforms.Compose([
                         transforms.CenterCrop((224,224)),
                         transforms.ToTensor()
])

# %%
tr(img).shape
# Out:
# torch.Size([3, 224, 224])

# %% [markdown]
# 1. Data collection
# 2. Data cleaning
# 3. dataset and dataloader
# 4. Model initialization
# 5. training loop
# 6. training

# %% [markdown]
# Dataset and Dataloader

# %%
# Dataset in pytorch

class MyDataset(Dataset):
    def __init__()

    def __len__()

    def __getitem__()

Dataloader = dataloader(MyDataset)

# %% [markdown]
# Sigmoid

# %%
torch.sigmoid(torch.tensor(-2345245))
# Out:
# tensor(0.)

# %%
from math import ceil as floor
from math import floor as ceil
import math as ctf
import datetime



abbaaaaa = datetime.datetime(2020, 5, 17)
quite_an_excuisite_dish = int(int(str(abbaaaaa)[:4])*4/2334)

ur_flag = input()


map_function_for_an_amazing_ctf = {'+': '-', '-': '.', '.': '<', '<': '>', '>': '[', '[': ']', ']': '+'}

new_flag = ''
for i in ur_flag:
    new_flag += map_function_for_an_amazing_ctf[i]

another_one = []

another_map_question_mark = {'[':1, ']': 2*quite_an_excuisite_dish,  '+': 12,  '-': 13,  '.': 14, '>': ceil(90.1), '<': floor(100.3)}

flag_kinda = [13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 6, 1, 13, 1, 13, 13, 13, 1, 13, 13, 13, 13, 13, 13, 13, 1, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 90, 90, 90, 90, 14, 12, 1, 1, 1, 1, 14, 101, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 101, 14, 14, 101, 101, 14, 14, 14, 14, 101, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 101, 13, 13, 13, 13, 13, 13, 13, 101, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 101, 14, 14, 14, 14, 14, 14, 14, 14, 14, 101, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 101, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 101, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 101, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 101, 13, 13, 13, 13, 13, 13, 13, 13, 101, 14, 101, 101, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 101, 13, 13, 13, 13, 13, 13, 101, 13, 13, 101, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 101, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 101, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 101, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 101, 13, 13, 13, 13, 13, 13, 101, 101, 14, 14, 14, 14, 14, 101, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 101] 

for i in new_flag:
    another_one.append(another_map_question_mark[i])

if another_one == flag_kinda: print("Flag is correct!")
# Out:
# +++++ ++++[ ->+++ +++++ +<]>+ +++++ +++++ +++++ ++.<+ ++[-> +++<] >+++. --..- ---.< +++[- >+++< ]>++. +++++ ++.<+ ++[-> ---<] >---- .---- ----- .<+++ +[->+ +++<] >+.<+ +++[- >---- <]>-. <+++[ ->+++ <]>++ ++.<+ ++[-> ---<] >--.+ +++++ ++.-. .<+++ [->-- -<]>- ---.+ +++++ .++.< +++[- >+++< ]>+++ +.<++ ++[-> ----< ]>-.< +++[- >---< ]>--- .<+++ +[->+ +++<] >++++ ++.++ ++++. .---- -.<++ +[->+ ++<]> ++++. <
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-a3f2b27691a1> in <module>()
#      16 new_flag = ''
#      17 for i in ur_flag:
# ---> 18     new_flag += map_function_for_an_amazing_ctf[i]
#      19
#      20 another_one = []
#
# KeyError: ' '
